# %% [markdown]
# ## Custom Gates and Gate Implementations
#
# This notebook demonstrates how to work with user-defined quantum operations and gate implementations that go beyond the standard gate set.
#
# Each quantum operation is associated with one or more GateImplementations which translate the high-level concepts to lower-level instructions accepted by the IQM server. This example shows how the user can
#
# -  Selecting a non-default implementation for a gate
#
# -  Add a custom implementation for an existing gate
#
# -  Add a custom gate and a custom implementation for it
#
#     -   by using existing gates as building blocks (composite gates)
#
# -  Defining new pulse waveforms for implementations

# %% [markdown]
# # Environment setup

# %%
#%%capture 
# !pip install "iqm-pulla==12.0.2" 
# !pip install iqm-client
# !pip install qiskit-iqm
# !pip install matplotlib
# !pip install pylatexenc

from pprint import pprint
# from iqm.qiskit_iqm import IQMProvider
from iqm.qiskit_iqm.iqm_transpilation import optimize_single_qubit_gates
from iqm.pulla.pulla import Pulla
from iqm.pulla.utils_qiskit import qiskit_to_pulla
from iqm.pulse.playlist.visualisation.base import inspect_playlist
from IPython.core.display import HTML
import logging
# Out:
# Collecting iqm-pulla==12.0.2
#   Obtaining dependency information for iqm-pulla==12.0.2 from https://files.pythonhosted.org/packages/b1/ae/11519af1a3b239be1b66a38d2ddeea53625025de508e972510e847b5f3e0/iqm_pulla-12.0.2-py3-none-any.whl.metadata
#   Using cached iqm_pulla-12.0.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: iqm-data-definitions<3.0,>=2.18 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulla==12.0.2) (2.20)
# Requirement already satisfied: pylatexenc==2.10 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulla==12.0.2) (2.10)
# Requirement already satisfied: pydantic<3.0,>=2.10.4 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulla==12.0.2) (2.12.5)
# Collecting iqm-client<34,>=33.0.2 (from iqm-pulla==12.0.2)
#   Obtaining dependency information for iqm-client<34,>=33.0.2 from https://files.pythonhosted.org/packages/48/87/6f2d74336afa323499cdc0ee6f708254a3f0a1e1e3320896b1a84a4481af/iqm_client-33.0.2-py3-none-any.whl.metadata
#   Using cached iqm_client-33.0.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: iqm-exa-common<28,>=27.4.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulla==12.0.2) (27.4.2)
# Requirement already satisfied: iqm-pulse<13,>=12.7.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulla==12.0.2) (12.7.2)
# Requirement already satisfied: iqm-station-control-client<13,>=12.0.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulla==12.0.2) (12.0.2)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client<34,>=33.0.2->iqm-pulla==12.0.2) (2.4.0)
# Requirement already satisfied: packaging==24.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client<34,>=33.0.2->iqm-pulla==12.0.2) (24.1)
# Requirement already satisfied: requests==2.32.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client<34,>=33.0.2->iqm-pulla==12.0.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<34,>=33.0.2->iqm-pulla==12.0.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<34,>=33.0.2->iqm-pulla==12.0.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<34,>=33.0.2->iqm-pulla==12.0.2) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<34,>=33.0.2->iqm-pulla==12.0.2) (2026.1.4)
# Requirement already satisfied: protobuf<5.0,>=4.25.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulla==12.0.2) (4.25.8)
# Requirement already satisfied: types-protobuf in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulla==12.0.2) (6.32.1.20251210)
# Requirement already satisfied: scipy<1.16.2,>=1.11.4 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulla==12.0.2) (1.15.3)
# Requirement already satisfied: scipy-stubs in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.18->iqm-pulla==12.0.2) (1.17.0.0)
# Requirement already satisfied: python-dotenv==0.21.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (0.21.1)
# Requirement already satisfied: xarray==2024.10.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (2024.10.0)
# Requirement already satisfied: types-requests in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (2.32.4.20260107)
# Requirement already satisfied: ruamel-yaml==0.17.32 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (0.17.32)
# Requirement already satisfied: ruamel-yaml-clib==0.2.8 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (0.2.8)
# Requirement already satisfied: jinja2==3.0.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (3.0.3)
# Requirement already satisfied: six==1.16.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (1.16.0)
# Requirement already satisfied: types-six in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (1.17.0.20251009)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from jinja2==3.0.3->iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (3.0.3)
# Requirement already satisfied: pandas>=2.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (2.3.3)
# Requirement already satisfied: python-rapidjson==1.20 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.2->iqm-pulla==12.0.2) (1.20)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0,>=1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.25.0)
# Requirement already satisfied: grpcio<2.0,>=1.65.4 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.76.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (6.0)
# Requirement already satisfied: tqdm>=4.59.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (4.67.1)
# Requirement already satisfied: types-tqdm in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (4.67.0.20250809)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.10.4->iqm-pulla==12.0.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.10.4->iqm-pulla==12.0.2) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.10.4->iqm-pulla==12.0.2) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.10.4->iqm-pulla==12.0.2) (0.4.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.25.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.72.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk~=1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (1.25.0)
# Requirement already satisfied: optype[numpy]<0.16,>=0.14.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from scipy-stubs->iqm-data-definitions<3.0,>=2.18->iqm-pulla==12.0.2) (0.15.0)
# Requirement already satisfied: numpy-typing-compat<20251207,>=20250818.1.25 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-data-definitions<3.0,>=2.18->iqm-pulla==12.0.2) (20251206.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-pulla==12.0.2) (2025.3)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (2.0.1)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (7.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-sdk~=1.25.0->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (0.46b0)
# Requirement already satisfied: zipp>=0.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-pulla==12.0.2) (3.23.0)
# Using cached iqm_pulla-12.0.2-py3-none-any.whl (69 kB)
# Using cached iqm_client-33.0.2-py3-none-any.whl (148 kB)
# Installing collected packages: iqm-client, iqm-pulla
#   Attempting uninstall: iqm-client
#     Found existing installation: iqm-client 22.9
#     Uninstalling iqm-client-22.9:
#       Successfully uninstalled iqm-client-22.9
#   Attempting uninstall: iqm-pulla
#     Found existing installation: iqm-pulla 12.0.1
#     Uninstalling iqm-pulla-12.0.1:
#       Successfully uninstalled iqm-pulla-12.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qiskit-iqm 18.2 requires iqm-client<22.10,>=22.9, but you have iqm-client 33.0.2 which is incompatible.
# Successfully installed iqm-client-33.0.2 iqm-pulla-12.0.2
# Requirement already satisfied: iqm-client in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (33.0.2)
# Requirement already satisfied: numpy<3.0,>=1.26.4 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client) (2.4.0)
# Requirement already satisfied: packaging==24.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client) (24.1)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client) (2.12.5)
# Requirement already satisfied: requests==2.32.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client) (2.32.3)
# Requirement already satisfied: iqm-pulse<13,>=12.7.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client) (12.7.2)
# Requirement already satisfied: iqm-station-control-client<13,>=12.0.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client) (12.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client) (2026.1.4)
# Requirement already satisfied: iqm-data-definitions<3.0,>=2.18 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.2->iqm-client) (2.20)
# Requirement already satisfied: python-rapidjson==1.20 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.2->iqm-client) (1.20)
# Requirement already satisfied: jinja2==3.0.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.2->iqm-client) (3.0.3)
# Requirement already satisfied: scipy<1.16,>=1.11.4 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.2->iqm-client) (1.15.3)
# Requirement already satisfied: scipy-stubs in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-pulse<13,>=12.7.2->iqm-client) (1.17.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from jinja2==3.0.3->iqm-pulse<13,>=12.7.2->iqm-client) (3.0.3)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0,>=1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (1.25.0)
# Requirement already satisfied: protobuf<5.0,>=4.25.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (4.25.8)
# Requirement already satisfied: types-protobuf in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (6.32.1.20251210)
# Requirement already satisfied: grpcio<2.0,>=1.65.4 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (1.76.0)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (6.0)
# Requirement already satisfied: types-requests in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (2.32.4.20260107)
# Requirement already satisfied: tqdm>=4.59.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (4.67.1)
# Requirement already satisfied: types-tqdm in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (4.67.0.20250809)
# Requirement already satisfied: iqm-exa-common<28,>=27.4.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-station-control-client<13,>=12.0.2->iqm-client) (27.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client) (0.4.2)
# Requirement already satisfied: python-dotenv==0.21.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (0.21.1)
# Requirement already satisfied: xarray==2024.10.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (2024.10.0)
# Requirement already satisfied: ruamel-yaml==0.17.32 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (0.17.32)
# Requirement already satisfied: ruamel-yaml-clib==0.2.8 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (0.2.8)
# Requirement already satisfied: six==1.16.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.16.0)
# Requirement already satisfied: types-six in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.17.0.20251009)
# Requirement already satisfied: pandas>=2.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (2.3.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.25.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.3.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.72.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk~=1.25.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (1.25.0)
# Requirement already satisfied: optype[numpy]<0.16,>=0.14.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from scipy-stubs->iqm-pulse<13,>=12.7.2->iqm-client) (0.15.0)
# Requirement already satisfied: numpy-typing-compat<20251207,>=20250818.1.25 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from optype[numpy]<0.16,>=0.14.0->scipy-stubs->iqm-pulse<13,>=12.7.2->iqm-client) (20251206.2.4)
# Requirement already satisfied: wrapt<3,>=1.10 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (2.0.1)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (7.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from opentelemetry-sdk~=1.25.0->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (0.46b0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<28,>=27.4.2->iqm-station-control-client<13,>=12.0.2->iqm-client) (2025.3)
# Requirement already satisfied: zipp>=0.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<13,>=12.0.2->iqm-client) (3.23.0)
# Requirement already satisfied: qiskit-iqm in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (18.2)
# Requirement already satisfied: numpy in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit-iqm) (2.4.0)
# Requirement already satisfied: qiskit<1.3,>=1.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit-iqm) (1.2.4)
# Requirement already satisfied: qiskit-aer<0.16,>=0.13.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit-iqm) (0.15.1)
# Collecting iqm-client<22.10,>=22.9 (from qiskit-iqm)
#   Obtaining dependency information for iqm-client<22.10,>=22.9 from https://files.pythonhosted.org/packages/c0/1a/c8e3d495720acb227d6b6718a3cbafbeb2ed106c83c6d3f4be5c83af3390/iqm_client-22.9-py3-none-any.whl.metadata
#   Using cached iqm_client-22.9-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging==24.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client<22.10,>=22.9->qiskit-iqm) (24.1)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client<22.10,>=22.9->qiskit-iqm) (2.12.5)
# Requirement already satisfied: requests==2.32.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from iqm-client<22.10,>=22.9->qiskit-iqm) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<22.10,>=22.9->qiskit-iqm) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<22.10,>=22.9->qiskit-iqm) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<22.10,>=22.9->qiskit-iqm) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from requests==2.32.3->iqm-client<22.10,>=22.9->qiskit-iqm) (2026.1.4)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (1.15.3)
# Requirement already satisfied: sympy>=1.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (1.14.0)
# Requirement already satisfied: dill>=0.3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (0.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (5.6.0)
# Requirement already satisfied: typing-extensions in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (4.15.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit<1.3,>=1.0->qiskit-iqm) (0.13.0)
# Requirement already satisfied: psutil>=5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from qiskit-aer<0.16,>=0.13.1->qiskit-iqm) (7.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client<22.10,>=22.9->qiskit-iqm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client<22.10,>=22.9->qiskit-iqm) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client<22.10,>=22.9->qiskit-iqm) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from python-dateutil>=2.8.0->qiskit<1.3,>=1.0->qiskit-iqm) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from sympy>=1.3->qiskit<1.3,>=1.0->qiskit-iqm) (1.3.0)
# Using cached iqm_client-22.9-py3-none-any.whl (52 kB)
# Installing collected packages: iqm-client
#   Attempting uninstall: iqm-client
#     Found existing installation: iqm-client 33.0.2
#     Uninstalling iqm-client-33.0.2:
#       Successfully uninstalled iqm-client-33.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# iqm-pulla 12.0.2 requires iqm-client<34,>=33.0.2, but you have iqm-client 22.9 which is incompatible.
# Successfully installed iqm-client-22.9
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pylatexenc in /opt/miniconda3/envs/oak/lib/python3.11/site-packages (2.10)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 10
#       8 from pprint import pprint
#       9 # from iqm.qiskit_iqm import IQMProvider
# ---> 10 from iqm.qiskit_iqm.iqm_transpilation import optimize_single_qubit_gates
#      11 from iqm.pulla.pulla import Pulla
#      12 from iqm.pulla.utils_qiskit import qiskit_to_pulla
#
# ModuleNotFoundError: No module named 'iqm.qiskit_iqm.iqm_transpilation'

# %%
from iqm.pulla.pulla import Pulla
import os
from iqm.iqm_client.authentication import TokenManager

# On-premise
#os.environ["IQM_TOKENS_FILE"]="your-token-here"
#p = Pulla("your-url-here", get_token_callback=TokenManager().get_bearer_token) 
#cocos_url = os.environ["IQM_TOKENS_FILE"]
#provider = IQMProvider(cocos_url)
#backend = provider.get_backend()

#Resonance 

#quantum_computer_url = os.environ.get("https://cocos.resonance.meetiqm.com/sirius") 
#api_token = os.environ.get("RESONANCE_API_TOKEN")

#p = Pulla(quantum_computer_url, get_token_callback=lambda: f"Bearer {api_token}")
#provider = IQMProvider(quantum_computer_url, token=api_token)
#backend = provider.get_backend()

#Resonance
api_token = "g+CJ8vynqN+10tusagrRHxsEs1haEFK3KOsLamj8eP0Bm5hqfa594ZpuVXwfh0Ds"
quantum_computer_url = os.environ.get("https://cocos.resonance.meetiqm.com/garnet") 
p = Pulla("https://cocos.resonance.meetiqm.com/garnet", get_token_callback=lambda: api_token) 
provider = IQMProvider(quantum_computer_url, token=api_token)
#backend = provider.get_backend()
backend = IQMProvider("https://cocos.resonance.meetiqm.com/garnet", token=api_token).get_backend()#compiler = p.get_standard_compiler()

# RY+7teYoloAZmiaqtizATJxU4Uz6yWP8AsPQ6riQz/8Giwx/pGJ3vIAAfl/fP/po
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from iqm.pulla.pulla import Pulla
#       2 import os
#       3 from iqm.iqm_client.authentication import TokenManager
#
# File /opt/miniconda3/envs/oak/lib/python3.11/site-packages/iqm/pulla/pulla.py:40
#      38 from iqm.cpc.compiler.standard_stages import get_standard_stages
#      39 from iqm.cpc.interface.compiler import CircuitExecutionOptions
# ---> 40 from iqm.pulla.calibration import CalibrationDataProvider
#      41 from iqm.pulla.interface import (
#      42     CalibrationSetValues,
#      43     CHADRetrievalException,
#      44     ChipLabelRetrievalException,
#      45     SettingsRetrievalException,
#      46 )
#      47 from iqm.pulla.utils import extract_readout_controller_result_names, map_sweep_results_to_logical_qubits
#
# File /opt/miniconda3/envs/oak/lib/python3.11/site-packages/iqm/pulla/calibration.py:23
#      19 from uuid import UUID
#      21 from iqm.iqm_server_client.iqm_server_client import _IQMServerClient
# ---> 23 from iqm.pulla.interface import CalibrationSetValues
#      24 from iqm.pulla.utils import calset_from_observations
#      25 from iqm.station_control.interface.models import StrUUID
#
# ImportError: cannot import name 'CalibrationSetValues' from 'iqm.pulla.interface' (/opt/miniconda3/envs/oak/lib/python3.11/site-packages/iqm/pulla/interface.py)

# %%
from qiskit import QuantumCircuit
from qiskit.compiler import transpile


def example_qiskit_circuit():
    qc = QuantumCircuit(2, 2)
    qc.x(0)
    qc.cx(0, 1)
    qc.h(0)
    qc.measure_all()

    transpiled_qc = transpile(qc, backend=backend, layout_method='sabre', optimization_level=3)
    transpiled_qc = optimize_single_qubit_gates(transpiled_qc)
    return transpiled_qc


example_qiskit_circuit().draw(output='mpl', style='clifford', idle_wires=False)

# %% [markdown]
# # Changing implementations at the circuit level
#
# Circuits are usually defined without specifying implementations for any of the gates. The implementations available in a given calibration set are listed in the corresponding dynamic quantum architecture, through Cocos.
#
# Let’s see a list of available implementations, with their parameters:

# %%
circuits, compiler = qiskit_to_pulla(p, backend, example_qiskit_circuit())

compiler.print_all_implementations_trees()

# %% [markdown]
# You can specify a default implementation for each native operation type in the circuit, and then override it for specific loci. Let’s change all cz gates to use the slepian implementation, and make an execption for the qubit pair (QB1, QB2).

# %%
compiler.set_default_implementation('cz', 'slepian')
compiler.set_default_implementation_for_loci('cz', 'tgss', [('QB1', 'QB2')])

# %% [markdown]
# Note that the default implementations are merely suggestions to the compiler. If the compiler does not have calibration data for a default implementation, it will ignore it and use what it can.
#
# You can also force the compiler to use a specific implementation for each circuit instruction separately in the IQM Pulse native format, which describes a circuit as a list of CircuitOperation instances.

# %% [markdown]
# # Custom gates: Composite gates
#
# IQM Pulse allows the user to define composite gates: gates consisting of other registered gates. Composite gates are particularly useful because they allow reusing the calibrated of data of the other gates. Furthermore, it is possible to use different calibration data for the registered gates inside a composite gate than outside it.
#
# Let’s define a prx implementation that acts like a normal prx, except it implements x with 2 pulses with a 100 ns wait between them. The __call__ method produces a TimeBox using IQM Pulse’s ScheduleBuilder. It’s worth mentioning that the composite gate is not restricted to using only registered gates; it could equally well return a TimeBox with lower level instructions.

# %%
from iqm.pulse.gate_implementation import CompositeGate
import numpy as np


class StretchedX(CompositeGate):
    registered_gates = ['prx']  # use the standard prx as a building block

    def __call__(self, angle_t: float, phase_t: float):
        normal_prx = self.build("prx", self.locus)
        # convert args to radians, which is what prx uses on the schedule level
        phase = phase_t * 2 * np.pi
        angle = angle_t * 2 * np.pi
        if angle_t != 0.5:
            return normal_prx(angle, phase)

        half = normal_prx(np.pi / 2, phase)
        return half + self.builder.wait(self.locus, 100e-9, rounding=True) + half

# %% [markdown]
# Now we register a new gate custom_x, which StretchedX implements. We want to make it compatible with the circuit-level prx, so we declare that it has the same parameters. Then we change the fist prx in the IQM Pulse circuit to use our new implementation.

# %%
circuits, compiler = qiskit_to_pulla(p, backend, example_qiskit_circuit())
compiler.add_implementation('custom_x', 'StretchedX', StretchedX, quantum_op_specs={'params': ('angle_t', 'phase_t')})

c = circuits[0]
for inst in c.instructions:
    if inst.name == 'prx':
        inst.name = 'custom_x'

playlist, _ = compiler.compile(circuits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 circuits, compiler = qiskit_to_pulla(p, backend, example_qiskit_circuit())
#       2 compiler.add_implementation('custom_x', 'StretchedX', StretchedX, quantum_op_specs={'params': ('angle_t', 'phase_t')})
#       4 c = circuits[0]
#
# NameError: name 'qiskit_to_pulla' is not defined

# %% [markdown]
# Inspecting the schedule, we can see that the X gate in the circuit is indeed split into two pulses with a wait in between:

# %%
HTML(inspect_playlist(playlist, [0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 HTML(inspect_playlist(playlist, [0]))
#
# NameError: name 'HTML' is not defined

# %% [markdown]
# # Custom gates: Custom waveforms
#
# Finally, let’s change the pulse waveforms of an existing gate. The tricky part of this is that we need to provide the calibration data by hand. IQM Pulse provides several “gate with custom waveforms” base classes so that users need only write the waveforms.
#
# Let’s define a new implementation of PRX using a raised cosine pulse:

# %%
from iqm.pulse.gates.prx import PRX_CustomWaveforms
from dataclasses import dataclass
from iqm.pulse.playlist.waveforms import Gaussian, GaussianDerivative, Waveform
import numpy as np


@dataclass(frozen=True)
class RaisedCosine(Waveform):
    r"""Raised cosine pulse.

    .. math::
        f(t) = \frac{1}{2} (1 + \cos((t - c) \pi / w)) \quad \text{when} \: |t - c| \le w, 0 \: \text{otherwise}

    where :math:`c` is :attr:`center_offset`, and :math:`w` is :attr:`width`.
    The raised cosine has a finite support.

    Args:
        width: half-width of the support
        center_offset: center offset
    """

    width: float
    center_offset: float = 0.0

    def _sample(self, sample_coords: np.ndarray) -> np.ndarray:
        offset_coords = sample_coords - self.center_offset
        return np.where(
            np.abs(offset_coords) <= self.width,
            0.5 * (1 + np.cos(offset_coords * np.pi / self.width)),
            0.0,
        )


@dataclass(frozen=True)
class RaisedCosineDerivative(Waveform):
    r"""Scaled derivative of the RaisedCosine pulse.

    .. math::
        f(t) = -\sin((t - c) \pi / w) \quad \text{when} \: |t - c| \le w, 0 \: \text{otherwise}

    where :math:`c` is :attr:`center_offset`, and :math:`w` is :attr:`width`.

    Args:
        width: half-width of the support
        center_offset: center offset
    """

    width: float
    center_offset: float = 0.0

    def _sample(self, sample_coords: np.ndarray) -> np.ndarray:
        offset_coords = sample_coords - self.center_offset
        return np.where(
            np.abs(offset_coords) <= self.width,
            -0.5 * np.sin(offset_coords * np.pi / self.width),
            0.0,
        )


class PRX_RaisedCosine(PRX_CustomWaveforms, wave_i=RaisedCosine, wave_q=RaisedCosineDerivative):
    """Implementation of PRX using a raised cosine pulse."""

    center_offset: float = 0.0

# %% [markdown]
# The class attributes of the waveforms define the calibration data they require. The PRX_CustomWaveforms class adds some more. We can add the new prx implementation to the compiler, and check what calibration data it needs:

# %%
circuits, compiler = qiskit_to_pulla(p, backend, example_qiskit_circuit())

compiler.add_implementation('prx', 'raised_cosine', PRX_RaisedCosine)
compiler.print_implementations_trees(compiler.builder.op_table['prx'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 circuits, compiler = qiskit_to_pulla(p, backend, example_qiskit_circuit())
#       3 compiler.add_implementation('prx', 'raised_cosine', PRX_RaisedCosine)
#       4 compiler.print_implementations_trees(compiler.builder.op_table['prx'])
#
# NameError: name 'qiskit_to_pulla' is not defined

# %% [markdown]
# Let us then make one of the prx gates in the circuit use our new implementation:

# %%
circuits[0].instructions[0].implementation = "raised_cosine"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 circuits[0].instructions[0].implementation = "raised_cosine"
#
# NameError: name 'circuits' is not defined

# %% [markdown]
# Compiling this circuit right now would fail with an error:

# %%
Error in stage "circuit" pass "map_implementations_for_loci": Circuit 0: No calibration data for 'prx.raised_cosine' at ('QB1',).
# Out:
#   Cell In[7], line 1
#     Error in stage "circuit" pass "map_implementations_for_loci": Circuit 0: No calibration data for 'prx.raised_cosine' at ('QB1',).
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# (The locus (‘QB1’,) may differ in your output due to the stochastic nature of routing.)
#
# The point is that the compiler does not have necessary calibration data for this new implementation. One way to fix this is to amend the current calibration. The numbers here are arbitrary, in reality you would need to calibrate the gate parameters somehow.

# %%
custom_cal_data = {
    "duration": 40e-09,
    "amplitude_i": 0.1662,
    "amplitude_q": -0.00802,
    "width": 20e-9,
    "center_offset": 3e-9,
}

for qubit in compiler.builder.chip_topology.qubits:
    compiler.amend_calibration_for_gate_implementation('prx', 'raised_cosine', (qubit,), custom_cal_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       1 custom_cal_data = {
#       2     "duration": 40e-09,
#       3     "amplitude_i": 0.1662,
#    (...)
#       6     "center_offset": 3e-9,
#       7 }
# ----> 9 for qubit in compiler.builder.chip_topology.qubits:
#      10     compiler.amend_calibration_for_gate_implementation('prx', 'raised_cosine', (qubit,), custom_cal_data)
#
# NameError: name 'compiler' is not defined

# %% [markdown]
# Data with gates.prx.raised_cosine.* is now visible in compiler.get_calibration(). Note that we added the same calibration data to all qubits. In practice, this rarely makes sense, because each qubit is usually calibrated differently.
#
# Now the compilation succeeds and we see that raised_cosine was used once. Using the schedule visualization you could also verify that the pulse shape is indeed different on the first prx instance.

# %%
playlist, context = compiler.compile(circuits)
pprint(context['circuit_metrics'][0].gate_loci["prx"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 playlist, context = compiler.compile(circuits)
#       2 pprint(context['circuit_metrics'][0].gate_loci["prx"])
#
# NameError: name 'compiler' is not defined

# %%
HTML(inspect_playlist(playlist, [0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 HTML(inspect_playlist(playlist, [0]))
#
# NameError: name 'HTML' is not defined
